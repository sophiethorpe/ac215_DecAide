# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import re
import pandas as pd
import numpy as np
import time
import asyncio
from requests_html import HTMLSession, AsyncHTMLSession

# %%
# URL to scrape
base_url = "https://www.vogue.com/fashion-shows/seasons"

# %%
# Function to get all the fashion show and slideshow URLs under /seasons
def get_fashion_season_urls(base_url):
    # Request the main seasons page
    response = requests.get(base_url)
    if response.status_code != 200:
        print(f"Failed to retrieve the page: {response.status_code}")
        return []

    # Parse the page content
    soup = BeautifulSoup(response.content, "html.parser")

    # Find all 'a' tags that contain fashion show URLs
    show_urls = []
    for a_tag in soup.find_all('a', href=True):
        href = a_tag['href']
        # Filter URLs that contain "/fashion-shows/" and are not general category pages
        if "/fashion-shows/" in href and not href.endswith(("seasons", "latest-shows", "designers", "featured", "image-archive")):
            # Create full URL by joining base URL with relative paths
            full_url = urljoin(base_url, href)
            # Append the full URL to the list
            show_urls.append(full_url)

    # Remove duplicates
    show_urls = list(set(show_urls))

    return show_urls

    
# Function to get all slideshow URLs from a single fashion show page
def get_show_urls(show_url, verbose=False):
    slideshow_links = []
    show_name = re.sub("^.*fashion-shows/", '', show_url)
    if verbose: print(show_name)
    
    # Find slideshow links (ending with #1, #2, etc.)
    pattern = re.compile(r'.*SummaryItem.*')

    for _ in range(50):
        response = requests.get(show_url)
        if response.status_code != 200:
            print(f"Failed to retrieve the show page: {response.status_code}")
            return []

        soup = BeautifulSoup(response.content, "html.parser")

        for a_tag in soup.find_all('a', {'class': pattern}):
            href = a_tag.get('href')
            if show_name in href:
                full_url = urljoin(show_url, href)
                full_url += "/slideshow/collection#1"
                slideshow_links.append(full_url)
        
        if len(slideshow_links) > 0: break
    
    # Remove duplicates and return slideshow URLs
    if len(slideshow_links) > 0: return list(set(slideshow_links))
    else: print("WARNING:", show_name, "NOT CONNECTED")

# %%
# Call the function and print the result
fashion_season_urls = get_fashion_season_urls(base_url)

shows_urls = list(map(lambda item: get_show_urls(item, verbose=True), fashion_season_urls))
# print(shows_urls)
# Out:
# bridal-fall-2018
# fall-2012-ready-to-wear
# resort-2025
# lagos-spring-2024
# copenhagen-spring-2022
# australia-spring-2015
# spring-2015-menswear
# fall-1996-couture
# sao-paulo-resort-2017
# kiev-spring-2019
# resort-2019
# resort-2007
# spring-2009-couture
# madrid-fall-2023
# spring-2021-ready-to-wear
# fall-2004-ready-to-wear
# fall-2021-ready-to-wear
# spring-2009-menswear
# seoul-spring-2018
# berlin-fall-2017
# fall-2024-ready-to-wear
# kiev-spring-2016
# tbilisi-fall-2018
# fall-2007-couture
# fall-1989-ready-to-wear
# fall-2002-menswear
# fall-1994-ready-to-wear
# copenhagen-spring-2019
# pre-fall-2024-menswear
# resort-2012
# pre-fall-2025
# shanghai-fall-2024
# resort-2016
# spring-1992-ready-to-wear
# fall-1988-ready-to-wear
# fall-2000-couture
# spring-2022-ready-to-wear
# stockholm-fall-2019
# fall-2011-menswear
# spring-1999-menswear
# shanghai-spring-2023
# kiev-spring-2018
# berlin-spring-2025
# spring-2008-couture
# fall-2013-menswear
# tbilisi-fall-2017
# tokyo-spring-2024
# fall-2010-ready-to-wear
# resort-2021
# ukraine-fall-2016
# bridal-fall-2019
# spring-1995-ready-to-wear
# spring-1990-ready-to-wear
# spring-2017-menswear
# fall-2015-couture
# tokyo-fall-2021
# seoul-fall-2018
# pre-fall-2019
# russia-spring-2018
# pre-fall-2022-menswear
# ukraine-spring-2017
# tokyo-fall-2016
# spring-2000-menswear
# spring-2007-ready-to-wear
# spring-1998-menswear
# spring-1997-ready-to-wear
# seoul-spring-2017
# fall-2016-menswear
# stockholm-spring-2017
# berlin-spring-2017
# madrid-fall-2020
# mexico-fall-2023
# spring-2025-ready-to-wear
# fall-2007-menswear
# spring-2002-couture
# bridal-spring-2020
# fall-2002-couture
# fall-2005-couture
# spring-2011-couture
# kiev-spring-2017
# fall-2000-ready-to-wear
# fall-2014-ready-to-wear
# fall-2006-couture
# tokyo-spring-2019
# pre-fall-2014
# spring-2016-menswear
# pre-fall-2017
# resort-2010
# copenhagen-spring-2023
# berlin-spring-2022
# tokyo-fall-2020
# copenhagen-fall-2024
# resort-2018
# fall-2024-couture
# tokyo-spring-2025
# fall-2001-ready-to-wear
# pre-fall-2015
# spring-2012-menswear
# tokyo-spring-2016
# spring-1994-ready-to-wear
# fall-2022-menswear
# russia-fall-2016
# kiev-fall-2018
# stockholm-fall-2021
# spring-2021-menswear
# fall-1991-ready-to-wear
# mexico-city-resort-2022
# russia-spring-2016
# berlin-fall-2022
# spring-2021-couture
# tokyo-spring-2020
# kiev-fall-2015
# pre-fall-2013
# resort-2022
# tokyo-fall-2024
# tokyo-spring-2018
# tokyo-fall-2023
# ukraine-fall-2017
# spring-2004-couture
# resort-2015
# fall-2023-menswear
# stockholm-spring-2019
# spring-2002-menswear
# bridal-fall-2020
# resort-2025-menswear
# australia-resort-2022
# berlin-spring-2023
# copenhagen-spring-2024
# spring-2022-couture
# spring-2018-ready-to-wear
# fall-2015-menswear
# fall-2019-couture
# copenhagen-spring-2020
# berlin-fall-2015
# fall-1995-couture
# spring-2012-ready-to-wear
# berlin-fall-2023
# resort-2017
# fall-2004-couture
# fall-2017-couture
# fall-2018-menswear
# pre-fall-2024
# shanghai-spring-2024
# madrid-spring-2022
# fall-2005-menswear
# spring-1994-couture
# mexico-spring-2024
# bridal-spring-2016
# Failed to retrieve the show page: 502
# spring-2000-ready-to-wear
# sao-paolo-spring-2017
# pre-fall-2008
# spain-fall-2024
# fall-2021-couture
# spring-2023-menswear
# resort-2011
# spring-2005-ready-to-wear
# tokyo-fall-2017
# fall-2015-ready-to-wear
# spring-2019-couture
# fall-2023-ready-to-wear
# pre-fall-2010
# berlin-spring-2016
# madrid-fall-2021-ready-to-wear
# spring-1997-couture
# russia-fall-2017
# spring-2013-ready-to-wear
# spring-2003-ready-to-wear
# fall-1995-ready-to-wear
# tbilisi-spring-2019
# copenhagen-spring-2016
# fall-1997-couture
# madrid-spring-2023
# spring-2007-menswear
# spring-2023-couture
# fall-1999-menswear
# resort-2020
# copenhagen-spring-2017
# stockholm-fall-2016
# kiev-fall-2017
# spring-2014-ready-to-wear
# russia-fall-2015
# spring-1996-ready-to-wear
# fall-2001-couture
# tbilisi-spring-2017
# spring-1999-couture
# spring-2016-couture
# pre-fall-2022
# spring-1988-couture
# spring-2002-ready-to-wear
# sao-paulo-fall-2016
# fall-2013-ready-to-wear
# bridal-spring-2017
# fall-2008-ready-to-wear
# fall-2017-menswear
# tokyo-fall-2022
# mexico-fall-2024
# fall-2022-ready-to-wear
# spring-2009-ready-to-wear
# fall-2009-ready-to-wear
# tokyo-fall-2019
# fall-2002-ready-to-wear
# bridal-spring-2018
# resort-2021-menswear
# copenhagen-fall-2016
# spring-2001-couture
# australia-resort-2023
# russia-spring-2017
# fall-2003-couture
# stockholm-fall-2022
# spring-1991-ready-to-wear
# spring-1993-couture
# copenhagen-fall-2023
# seoul-fall-2015
# spring-2010-couture
# bridal-spring-2021
# resort-2013
# spring-2019-menswear
# istanbul-spring-2021
# pre-fall-2012
# fall-2014-couture
# spring-2013-menswear
# berlin-spring-2024
# spring-2017-ready-to-wear
# bridal-fall-2017
# pre-fall-2020-menswear
# tokyo-fall-2018
# istanbul-fall-2021
# spring-2019-ready-to-wear
# spring-2011-ready-to-wear
# fall-2005-ready-to-wear
# fall-2009-menswear
# bridal-spring-2019
# stockholm-fall-2018
# fall-2016-ready-to-wear
# fall-2011-couture
# tokyo-spring-2017
# fall-2010-menswear
# spring-1998-couture
# fall-2009-couture
# spring-2011-menswear
# spring-2024-couture
# resort-2023-menswear
# tbilisi-spring-2018
# spring-2006-couture
# spring-2015-ready-to-wear
# fall-2006-menswear
# copenhagen-spring-2025
# berlin-fall-2021
# madrid-fall-2019
# fall-2007-ready-to-wear
# copenhagen-fall-2018
# tokyo-fall-2015
# fall-2021-menswear
# pre-fall-2016
# spring-2024-menswear
# australia-resort-2025
# copenhagen-spring-2018
# fall-2011-ready-to-wear
# stockholm-spring-2021
# resort-2024
# spring-1999-ready-to-wear
# tbilisi-spring-2016
# fall-2001-menswear
# seoul-fall-2016
# spring-2004-ready-to-wear
# pre-fall-2023
# spring-2020-couture
# fall-2018-ready-to-wear
# spring-2020-menswear
# spring-2018-menswear
# resort-2024-menswear
# shanghai-spring-2022
# spring-2014-couture
# spring-2003-couture
# spring-2010-ready-to-wear
# spring-2015-couture
# fall-1997-ready-to-wear
# spring-2001-ready-to-wear
# copenhagen-fall-2022
# fall-2018-couture
# fall-2024-menswear
# stockholm-fall-2017
# fall-1998-ready-to-wear
# pre-fall-2021
# spring-1996-couture
# australia-resort-2020
# shanghai-fall-2023
# tbilisi-fall-2016
# spring-2005-menswear
# berlin-fall-2016
# resort-2009
# fall-2014-menswear
# stockholm-fall-2015
# spring-2008-menswear
# fall-1988-couture
# pre-fall-2023-menswear
# spring-2008-ready-to-wear
# madrid-spring-2024
# spring-2003-menswear
# fall-1999-couture
# fall-2022-couture
# spring-2023-ready-to-wear
# fall-2013-couture
# resort-2008
# fall-2010-couture
# fall-2020-ready-to-wear
# madrid-spring-2020
# spring-2014-menswear
# madrid-fall-2022
# stockholm-spring-2023
# spring-2025-menswear
# fall-2020-menswear
# resort-2023
# copenhagen-fall-2019
# spring-2022-menswear
# stockholm-spring-2016
# spring-1998-ready-to-wear
# spring-2024-ready-to-wear
# mexico-city-spring-2022
# pre-fall-2011
# tokyo-spring-2023
# pre-fall-2009
# spring-1993-ready-to-wear
# seoul-fall-2017
# australia-resort-2017
# fall-1999-ready-to-wear
# pre-fall-2018
# fall-2012-menswear
# fall-2008-couture
# australia-resort-2024
# mexico-city-fall-2021
# australia-resort-2019
# spring-2000-couture
# fall-2019-ready-to-wear
# fall-2019-menswear
# fall-2008-menswear
# resort-2014
# spring-2012-couture
# spring-2013-couture
# tokyo-spring-2021
# mexico-city-fall-2022
# fall-2016-couture
# shanghai-fall-2022
# mexico-spring-2023
# copenhagen-fall-2017
# copenhagen-spring-2021
# tokyo-spring-2022
# spring-2007-couture
# fall-1992-ready-to-wear
# istanbul-fall-2015
# spring-2017-couture
# sao-paulo-spring-2015
# fall-2006-ready-to-wear
# spring-2006-ready-to-wear
# resort-2022-menswear
# spring-2010-menswear
# kiev-fall-2016
# pre-fall-2020
# stockholm-spring-2018
# fall-2020-couture
# bridal-fall-2016
# spring-2006-menswear
# australia-resort-2018
# spring-2018-couture
# berlin-fall-2024
# spring-2016-ready-to-wear
# fall-2003-menswear
# fall-2012-couture
# spring-2020-ready-to-wear
# fall-2003-ready-to-wear
# fall-1990-ready-to-wear
# fall-1993-ready-to-wear
# copenhagen-fall-2021
# spring-2005-couture
# fall-2017-ready-to-wear
# stockholm-spring-2022
# fall-1996-ready-to-wear
# fall-2023-couture
# seoul-spring-2016
# copenhagen-fall-2015

# %%
for i in range(len(shows_urls)):
    if len(shows_urls[i]) == 0:
        print(i, fashion_season_urls[i], shows_urls[i])
        print("RERUN")
        shows_urls[i] = get_show_urls(fashion_season_urls[i])
        print(shows_urls[i])

# %%
data_dict = {'season': [re.sub("^.*fashion-shows/", '', url) for url in fashion_season_urls],
        'season_url': fashion_season_urls,
        'show_url': shows_urls}

df_shows = pd.DataFrame(data_dict)
df_shows.to_csv('data/shows_season.csv', index_label='season_ID')

# %%
df_long = df_shows.explode('show_url')

# Reset the index if necessary
df_long = df_long.reset_index(drop=True)
df_long['year'] = df_long['season'].str.extract(r'(\d{4})')
df_long.to_csv('data/shows_season_long.csv', index_label='show_ID')

# %%
df_long
# Out:
#                     season                                         season_url  \
# 0         bridal-fall-2018  https://www.vogue.com/fashion-shows/bridal-fal...
# 1         bridal-fall-2018  https://www.vogue.com/fashion-shows/bridal-fal...
# 2         bridal-fall-2018  https://www.vogue.com/fashion-shows/bridal-fal...
# 3         bridal-fall-2018  https://www.vogue.com/fashion-shows/bridal-fal...
# 4         bridal-fall-2018  https://www.vogue.com/fashion-shows/bridal-fal...
# ...                    ...                                                ...
# 4305  copenhagen-fall-2015  https://www.vogue.com/fashion-shows/copenhagen...
# 4306  copenhagen-fall-2015  https://www.vogue.com/fashion-shows/copenhagen...
# 4307  copenhagen-fall-2015  https://www.vogue.com/fashion-shows/copenhagen...
# 4308  copenhagen-fall-2015  https://www.vogue.com/fashion-shows/copenhagen...
# 4309  copenhagen-fall-2015  https://www.vogue.com/fashion-shows/copenhagen...
#
#                                                show_url  year
# 0     https://www.vogue.com/fashion-shows/bridal-fal...  2018
# 1     https://www.vogue.com/fashion-shows/bridal-fal...  2018
# 2     https://www.vogue.com/fashion-shows/bridal-fal...  2018
# 3     https://www.vogue.com/fashion-shows/bridal-fal...  2018
# 4     https://www.vogue.com/fashion-shows/bridal-fal...  2018
# ...                                                 ...   ...
# 4305  https://www.vogue.com/fashion-shows/copenhagen...  2015
# 4306  https://www.vogue.com/fashion-shows/copenhagen...  2015
# 4307  https://www.vogue.com/fashion-shows/copenhagen...  2015
# 4308  https://www.vogue.com/fashion-shows/copenhagen...  2015
# 4309  https://www.vogue.com/fashion-shows/copenhagen...  2015
#
# [4310 rows x 4 columns]

# %%
# from selenium import webdriver
# from selenium.webdriver.chrome.service import Service
# from selenium.webdriver.common.by import By
# from webdriver_manager.chrome import ChromeDriverManager

# # Setup Chrome options
# options = webdriver.ChromeOptions()
# options.add_argument("--start-maximized")  # Start maximized
# options.add_argument("--no-sandbox")       # Bypass OS security model
# options.add_argument("--disable-dev-shm-usage")  # Overcome limited resource problems

# %%
div_pattern = re.compile(r'RunwayGalleryLookNumberText.*')

asession = AsyncHTMLSession()

df_long = pd.read_csv('data/shows_season_long.csv')

# %%
async def get_npic(url, max_retries=50, delay=1):
    attempt = 0
    while attempt < max_retries:
        try:
            response = await asession.get(url)
    
            # Render the JavaScript on the page (if needed)
            await response.html.arender()

            
            soup = BeautifulSoup(response.html.html, "html.parser")

            div = soup.find('div', {'class': div_pattern})

            if div:
                npics = int(div.text.strip().split()[-1])
                return (url, npics)  # return the found <div> with indentation
            else:
                attempt += 1
                continue
        except Exception as e:
            attempt += 1
            print(f"Error scraping {url}")

    return None


async def run_tasks(s):
    tasks = [get_npic(arg) for arg in s]
    results = await asyncio.gather(*tasks)
    return results

# %%
df_long['total_pics'] = pd.Series([None] * len(df_long))
df_long
# Out:
#       show_ID                season  \
# 0           0      bridal-fall-2018
# 1           1      bridal-fall-2018
# 2           2      bridal-fall-2018
# 3           3      bridal-fall-2018
# 4           4      bridal-fall-2018
# ...       ...                   ...
# 4305     4305  copenhagen-fall-2015
# 4306     4306  copenhagen-fall-2015
# 4307     4307  copenhagen-fall-2015
# 4308     4308  copenhagen-fall-2015
# 4309     4309  copenhagen-fall-2015
#
#                                              season_url  \
# 0     https://www.vogue.com/fashion-shows/bridal-fal...
# 1     https://www.vogue.com/fashion-shows/bridal-fal...
# 2     https://www.vogue.com/fashion-shows/bridal-fal...
# 3     https://www.vogue.com/fashion-shows/bridal-fal...
# 4     https://www.vogue.com/fashion-shows/bridal-fal...
# ...                                                 ...
# 4305  https://www.vogue.com/fashion-shows/copenhagen...
# 4306  https://www.vogue.com/fashion-shows/copenhagen...
# 4307  https://www.vogue.com/fashion-shows/copenhagen...
# 4308  https://www.vogue.com/fashion-shows/copenhagen...
# 4309  https://www.vogue.com/fashion-shows/copenhagen...
#
#                                                show_url  year total_pics
# 0     https://www.vogue.com/fashion-shows/bridal-fal...  2018       None
# 1     https://www.vogue.com/fashion-shows/bridal-fal...  2018       None
# 2     https://www.vogue.com/fashion-shows/bridal-fal...  2018       None
# 3     https://www.vogue.com/fashion-shows/bridal-fal...  2018       None
# 4     https://www.vogue.com/fashion-shows/bridal-fal...  2018       None
# ...                                                 ...   ...        ...
# 4305  https://www.vogue.com/fashion-shows/copenhagen...  2015       None
# 4306  https://www.vogue.com/fashion-shows/copenhagen...  2015       None
# 4307  https://www.vogue.com/fashion-shows/copenhagen...  2015       None
# 4308  https://www.vogue.com/fashion-shows/copenhagen...  2015       None
# 4309  https://www.vogue.com/fashion-shows/copenhagen...  2015       None
#
# [4310 rows x 6 columns]

# %%
npics_list = await run_tasks(df_long['show_url'])
npics_list

# %%
# Set up the Chrome driver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.set_page_load_timeout(15)

df_long['total_pics'][:100] = df_long['show_url'][:100].apply(get_npic)

# Close the Selenium WebDriver after scraping is complete
driver.quit()
# Out:
# Error scraping https://www.vogue.com/fashion-shows/bridal-fall-2018/marchesa/slideshow/collection#1
# Error scraping https://www.vogue.com/fashion-shows/bridal-fall-2018/elie-saab/slideshow/collection#1
# Error scraping https://www.vogue.com/fashion-shows/resort-2025/alexander-mcqueen/slideshow/collection#1
# Error scraping https://www.vogue.com/fashion-shows/lagos-spring-2024/orange-culture/slideshow/collection#1
# Error scraping https://www.vogue.com/fashion-shows/sao-paulo-resort-2017/patbo/slideshow/collection#1
# C:\Users\z1982\AppData\Local\Temp\ipykernel_27056\838144944.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_long['total_pics'][:100] = df_long['show_url'][:100].apply(get_npic)

# %%
df_long
# Out:
#       show_ID                season  \
# 0           0      bridal-fall-2018
# 1           1      bridal-fall-2018
# 2           2      bridal-fall-2018
# 3           3      bridal-fall-2018
# 4           4      bridal-fall-2018
# ...       ...                   ...
# 4305     4305  copenhagen-fall-2015
# 4306     4306  copenhagen-fall-2015
# 4307     4307  copenhagen-fall-2015
# 4308     4308  copenhagen-fall-2015
# 4309     4309  copenhagen-fall-2015
#
#                                              season_url  \
# 0     https://www.vogue.com/fashion-shows/bridal-fal...
# 1     https://www.vogue.com/fashion-shows/bridal-fal...
# 2     https://www.vogue.com/fashion-shows/bridal-fal...
# 3     https://www.vogue.com/fashion-shows/bridal-fal...
# 4     https://www.vogue.com/fashion-shows/bridal-fal...
# ...                                                 ...
# 4305  https://www.vogue.com/fashion-shows/copenhagen...
# 4306  https://www.vogue.com/fashion-shows/copenhagen...
# 4307  https://www.vogue.com/fashion-shows/copenhagen...
# 4308  https://www.vogue.com/fashion-shows/copenhagen...
# 4309  https://www.vogue.com/fashion-shows/copenhagen...
#
#                                                show_url  year total_pics
# 0     https://www.vogue.com/fashion-shows/bridal-fal...  2018         12
# 1     https://www.vogue.com/fashion-shows/bridal-fal...  2018         15
# 2     https://www.vogue.com/fashion-shows/bridal-fal...  2018         19
# 3     https://www.vogue.com/fashion-shows/bridal-fal...  2018         24
# 4     https://www.vogue.com/fashion-shows/bridal-fal...  2018         23
# ...                                                 ...   ...        ...
# 4305  https://www.vogue.com/fashion-shows/copenhagen...  2015       None
# 4306  https://www.vogue.com/fashion-shows/copenhagen...  2015       None
# 4307  https://www.vogue.com/fashion-shows/copenhagen...  2015       None
# 4308  https://www.vogue.com/fashion-shows/copenhagen...  2015       None
# 4309  https://www.vogue.com/fashion-shows/copenhagen...  2015       None
#
# [4310 rows x 6 columns]
